# %%
print("learning ")

# %%
import pandas as pd
data={"text":["pal","lal","ama","lala","paa","sws"],"age":[23,23,21,11,12,34]}
df=pd.DataFrame(data)
print(df.tail())
print(df.head())
print(df.shape)
print(df.columns)
print(df["age"].iloc[2])
# Out:
#    text  age
# 1   lal   23
# 2   ama   21
# 3  lala   11
# 4   paa   12
# 5   sws   34
#    text  age
# 0   pal   23
# 1   lal   23
# 2   ama   21
# 3  lala   11
# 4   paa   12
# (6, 2)
# Index(['text', 'age'], dtype='str')
# 21

# %%
import pandas as pd
df=pd.read_csv('text.csv')
print(df)
# Out:
#   name   age
# 0  pal     21
# 1  anj     20
# 2  pra     19
